# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for each group
total_volume = [50, 100, 150, 200, 250, 300, 350]

# Flexible Swap & Smart Charge
total_revenue_fs = [4395.75, 6538.5, 8313.25, 9460.5, 10000, 10180.5, 9308.25]
battery_cost_fs = [0, 2000, 5250, 8650, 13100, 17100, 21400]
charging_cost_fs = [4003.25, 9834.25, 16344.5, 23735.75, 30998, 38320.75, 45185.5]
penalty_cost_fs = [90, 120, 180, 300, 240, 480, 1350]
swap_income_fs = [8489, 18492.75, 30087.75, 42146.25, 54338, 66081.25, 77243.75]
monetary_income_fs = [4485.75, 6658.5, 8493.25, 9760.5, 10240, 10660.5, 10658.25]
service_rate_fs = [99.40, 99.60, 99.60, 99.50, 99.68, 99.47, 98.71]

# Non-Flexible Swap
total_revenue_nf = [4106, 5530.25, 6828.25, 8166.5, 8280.75, 7781.5, 5788.75]
battery_cost_nf = [200, 3050, 6600, 10450, 14600, 17700, 21000]
charging_cost_nf = [4053.75, 9659.5, 15884.75, 23046.25, 29811, 36582.25, 43027.5]
penalty_cost_nf = [120, 480, 720, 750, 1440, 2850, 5610]
swap_income_nf = [8479.75, 18719.75, 30033, 42412.75, 54131.75, 64913.75, 75426.25]
monetary_income_nf = [4226, 6010.25, 7548.25, 8916.5, 9720.75, 10631.5, 11398.75]
service_rate_nf = [99.20, 98.40, 98.40, 98.75, 98.08, 96.83, 94.66]

# Charge ASAP
total_revenue_ca = [2440.75, 3208, 3540.75, 3748.75, 3387.5, 2870.25, 1298]
battery_cost_ca = [0, 1750, 4650, 8000, 11900, 15850, 19600]
charging_cost_ca = [5959.5, 13178.5, 20919, 29298.25, 37165.5, 45092.25, 52377.25]
penalty_cost_ca = [90, 240, 390, 540, 660, 900, 2130]
swap_income_ca = [8490.25, 18376.5, 29499.75, 41587, 53113, 64712.5, 75405.25]
monetary_income_ca = [2530.75, 3448, 3930.75, 4288.75, 4047.5, 3770.25, 3428]
service_rate_ca = [99.40, 99.20, 99.13, 99.10, 99.12, 99.00, 97.97]

# Non-Flexible Swap & Charge ASAP
total_revenue_nf_ca = [2238, 2045, 2031.25, 1899, 1236, 225, -2022.5]
battery_cost_nf_ca = [0, 2600, 5950, 10050, 12850, 16350, 19300]
charging_cost_nf_ca = [5844.25, 13084, 20652.5, 29228.5, 36260, 43731.25, 50259]
penalty_cost_nf_ca = [270, 780, 1110, 1020, 2460, 3750, 6420]
swap_income_nf_ca = [8352.25, 18509, 29743.75, 42197.5, 52806, 64056.25, 73956.5]
monetary_income_nf_ca = [2508, 2825, 3141.25, 2919, 3696, 3975, 4397.5]
service_rate_nf_ca = [98.20, 97.40, 97.53, 98.30, 96.72, 95.83, 93.89]

styles = {
    'fs': {'color': (33/255, 29/255, 31/255), 'line': '-', 'marker': 'o'},  # Flexible Swap & Smart Charge
    'nf': {'color': (11/255, 112/255, 183/255), 'line': '--', 'marker': 's'},  # Non-Flexible Swap
    'ca': {'color': (242/255, 146/255, 33/255), 'line': ':', 'marker': '^'},  # Charge ASAP
    'nf_ca': {'color': (126/255, 204/255, 37/255), 'line': '-.', 'marker': 'd'}  # Non-Flexible Swap & Charge ASAP (new style)
}

# %%
# 1. Battery Cost vs Total Volume
plt.figure(figsize=(8, 6))
plt.plot(total_volume, battery_cost_fs, label='Flexible Swap & Smart Charge', linestyle=styles['fs']['line'], marker=styles['fs']['marker'], color=styles['fs']['color'])
plt.plot(total_volume, battery_cost_nf, label='Non-Flexible Swap', linestyle=styles['nf']['line'], marker=styles['nf']['marker'], color=styles['nf']['color'])
plt.plot(total_volume, battery_cost_ca, label='Charge ASAP', linestyle=styles['ca']['line'], marker=styles['ca']['marker'], color=styles['ca']['color'])
plt.title('Battery Cost vs Total Volume', fontsize=12)
plt.xlabel('Total Volume', fontsize=10)
plt.ylabel('Battery Cost', fontsize=10)
plt.legend(fontsize=8)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# 2. Charging Cost vs Total Volume
plt.figure(figsize=(8, 6))
plt.plot(total_volume, charging_cost_fs, label='Flexible Swap & Smart Charge', linestyle=styles['fs']['line'], marker=styles['fs']['marker'], color=styles['fs']['color'])
plt.plot(total_volume, charging_cost_nf, label='Non-Flexible Swap', linestyle=styles['nf']['line'], marker=styles['nf']['marker'], color=styles['nf']['color'])
plt.plot(total_volume, charging_cost_ca, label='Charge ASAP', linestyle=styles['ca']['line'], marker=styles['ca']['marker'], color=styles['ca']['color'])
plt.title('Charging Cost vs Total Volume', fontsize=12)
plt.xlabel('Total Volume', fontsize=10)
plt.ylabel('Charging Cost', fontsize=10)
plt.legend(fontsize=8)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# 3. Penalty Cost vs Total Volume
plt.figure(figsize=(8, 6))
plt.plot(total_volume, penalty_cost_fs, label='Flexible Swap & Smart Charge', linestyle=styles['fs']['line'], marker=styles['fs']['marker'], color=styles['fs']['color'])
plt.plot(total_volume, penalty_cost_nf, label='Non-Flexible Swap', linestyle=styles['nf']['line'], marker=styles['nf']['marker'], color=styles['nf']['color'])
plt.plot(total_volume, penalty_cost_ca, label='Charge ASAP', linestyle=styles['ca']['line'], marker=styles['ca']['marker'], color=styles['ca']['color'])
plt.title('Penalty Cost vs Total Volume', fontsize=12)
plt.xlabel('Total Volume', fontsize=10)
plt.ylabel('Penalty Cost', fontsize=10)
plt.legend(fontsize=8)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# 4. Swap Income vs Total Volume
plt.figure(figsize=(8, 6))
plt.plot(total_volume, swap_income_fs, label='Flexible Swap & Smart Charge', linestyle=styles['fs']['line'], marker=styles['fs']['marker'], color=styles['fs']['color'])
plt.plot(total_volume, swap_income_nf, label='Non-Flexible Swap', linestyle=styles['nf']['line'], marker=styles['nf']['marker'], color=styles['nf']['color'])
plt.plot(total_volume, swap_income_ca, label='Charge ASAP', linestyle=styles['ca']['line'], marker=styles['ca']['marker'], color=styles['ca']['color'])
plt.title('Swap Income vs Total Volume', fontsize=12)
plt.xlabel('Total Volume', fontsize=10)
plt.ylabel('Swap Income', fontsize=10)
plt.legend(fontsize=8)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


# Example data
total_volume = np.array([50, 100, 150, 200, 250, 300, 350])

# Monetary Income
monetary_income_fs = np.array([4485.75, 6658.5, 8493.25, 9760.5, 10240, 10660.5, 10658.25])
monetary_income_nf = np.array([4226, 6010.25, 7548.25, 8916.5, 9720.75, 10631.5, 11398.75])
monetary_income_ca = np.array([2530.75, 3448, 3930.75, 4288.75, 4047.5, 3770.25, 3428])
monetary_income_nf_ca = np.array([2508, 2825, 3141.25, 2919, 3696, 3975, 4397.5])

# Service Rate
service_rate_fs = np.array([99.40, 99.60, 99.60, 99.50, 99.68, 99.47, 98.71])
service_rate_nf = np.array([99.20, 98.40, 98.40, 98.75, 98.08, 96.83, 94.66])
service_rate_ca = np.array([99.40, 99.20, 99.13, 99.10, 99.12, 99.00, 97.97])
service_rate_nf_ca = np.array([98.20, 97.40, 97.53, 98.30, 96.72, 95.83, 93.89])


# Set global font properties for all plots
plt.rcParams.update({
    'font.family': 'Times New Roman',  # or 'Helvetica'
    'font.size': 12,  # Default font size for axis labels and ticks
    'lines.linewidth': 2,  # Line width for better visibility
    'axes.grid': True,  # Turn on grid
    'grid.alpha': 0.3  # Make the grid lighter to match SCI standards
})

# Create figure and axis
fig, ax1 = plt.subplots(figsize=(8, 8),dpi=200)

# Bar width
bar_width =10
index = total_volume

# Shift positions for each dataset
offset = bar_width * 0.5  # Adjust the spacing between groups
bars_fs = ax1.bar(index - 3*offset, monetary_income_fs, width=bar_width, label='Monetary Income (Flexible Swap & Smart Charge)', color=styles['fs']['color'], alpha=0.8)
bars_nf = ax1.bar(index - offset, monetary_income_nf, width=bar_width, label='Monetary Income (Non-Flexible Swap & Smart Charge)', color=styles['nf']['color'], alpha=0.8)
bars_ca = ax1.bar(index + offset, monetary_income_ca, width=bar_width, label='Monetary Income (Flexible Swap & Charge ASAP)', color=styles['ca']['color'], alpha=0.8)
bars_nf_ca = ax1.bar(index + 3 * offset, monetary_income_nf_ca, width=bar_width, label='Monetary Income (Non-Flexible Swap & Charge ASAP)', color=styles['nf_ca']['color'], alpha=0.8)

# Set the axis labels and title
ax1.set_xlabel('Total Volume', fontsize=12)
ax1.set_ylabel('Monetary Income', fontsize=12)
ax1.set_xticks(index)  # Align the x-ticks with the total volume
ax1.set_xticklabels(total_volume, fontsize=10)
ax1.set_ylim([0, 16000])

# Create second axis for Service Rate (right y-axis)
ax2 = ax1.twinx()
lines_fs, = ax2.plot(total_volume, service_rate_fs, label='Service Rate (Flexible Swap & Smart Charge)', linestyle=styles['fs']['line'], marker=styles['fs']['marker'], color=styles['fs']['color'], alpha=0.8)
lines_nf, = ax2.plot(total_volume, service_rate_nf, label='Service Rate (Non-Flexible Swap & Smart Charge)', linestyle=styles['nf']['line'], marker=styles['nf']['marker'], color=styles['nf']['color'], alpha=0.8)
lines_ca, = ax2.plot(total_volume, service_rate_ca, label='Service Rate (Flexible Swap & Charge ASAP)', linestyle=styles['ca']['line'], marker=styles['ca']['marker'], color=styles['ca']['color'], alpha=0.8)
lines_nf_ca, = ax2.plot(total_volume, service_rate_nf_ca, label='Service Rate (Non-Flexible Swap & Charge ASAP)', linestyle=styles['nf_ca']['line'], marker=styles['nf_ca']['marker'], color=styles['nf_ca']['color'], alpha=0.8)

# Set second axis labels
ax2.set_ylabel('Service Rate (%)', fontsize=12)
ax2.set_ylim([80, 100])

# Combine legends from both axes into one (Monetary Income and Service Rate separately)
lines = [lines_fs, lines_nf, lines_ca, lines_nf_ca]  # Lines for service rate
bars = [bars_fs, bars_nf, bars_ca, bars_nf_ca]  # Bars for monetary income

# Create combined legend
handles = lines + bars
labels = [line.get_label() for line in lines] + [bar.get_label() for bar in bars]

# Move the legend outside the plot
ax1.legend(handles, labels, fontsize=10, loc='upper center', bbox_to_anchor=(0.5, -0.15), borderaxespad=0.)

# Set grid and fine-tune layout
ax1.grid(True, which='both', axis='y', linestyle='--', alpha=0.7)
ax1.tick_params(axis='both', which='both', length=0)  # Remove tick marks for a cleaner look

# Set plot title
plt.title('Service Rate and Monetary Income vs Total Volume', fontsize=14)

# Fine-tune layout
fig.tight_layout()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Set global font properties for all plots
plt.rcParams.update({
    'font.family': 'Times New Roman',  # or 'Helvetica'
    'font.size': 12,  # Default font size for axis labels and ticks
    'lines.linewidth': 2,  # Line width for better visibility
    'axes.grid': True,  # Turn on grid
    'grid.alpha': 0.3  # Make the grid lighter to match SCI standards
})

# Create a 2x2 grid of subplots
fig, axs = plt.subplots(2, 2, figsize=(10, 12),dpi=200)

# Plot 1: Battery Cost vs Total Volume
axs[0, 0].plot(total_volume, battery_cost_fs, label='Flexible Swap & Smart Charge', linestyle=styles['fs']['line'], marker=styles['fs']['marker'], color=styles['fs']['color'], alpha=0.8)
axs[0, 0].plot(total_volume, battery_cost_nf, label='Non-Flexible Swap & Smart Charge', linestyle=styles['nf']['line'], marker=styles['nf']['marker'], color=styles['nf']['color'], alpha=0.8)
axs[0, 0].plot(total_volume, battery_cost_ca, label='Flexible Swap & Charge ASAP', linestyle=styles['ca']['line'], marker=styles['ca']['marker'], color=styles['ca']['color'], alpha=0.8)
axs[0, 0].plot(total_volume, battery_cost_nf_ca, label='Non-Flexible Swap & Charge ASAP', linestyle=styles['nf_ca']['line'], marker=styles['nf_ca']['marker'], color=styles['nf_ca']['color'], alpha=0.8)  # Using nf_ca style
axs[0, 0].set_title('Battery Cost vs Total Volume', fontsize=14)
axs[0, 0].set_xlabel('Total Volume', fontsize=12)
axs[0, 0].set_ylabel('Battery Cost', fontsize=12)
axs[0, 0].tick_params(axis='both', labelsize=10)  # Set tick label size
axs[0, 0].legend(loc='upper left', fontsize=10)
axs[0, 0].grid(True)

# Plot 2: Charging Cost vs Total Volume
axs[0, 1].plot(total_volume, charging_cost_fs, label='Flexible Swap & Smart Charge', linestyle=styles['fs']['line'], marker=styles['fs']['marker'], color=styles['fs']['color'], alpha=0.8)
axs[0, 1].plot(total_volume, charging_cost_nf, label='Non-Flexible Swap & Smart Charge', linestyle=styles['nf']['line'], marker=styles['nf']['marker'], color=styles['nf']['color'], alpha=0.8)
axs[0, 1].plot(total_volume, charging_cost_ca, label='Flexible Swap & Charge ASAP', linestyle=styles['ca']['line'], marker=styles['ca']['marker'], color=styles['ca']['color'], alpha=0.8)
axs[0, 1].plot(total_volume, charging_cost_nf_ca, label='Non-Flexible Swap & Charge ASAP', linestyle=styles['nf_ca']['line'], marker=styles['nf_ca']['marker'], color=styles['nf_ca']['color'], alpha=0.8)  # Using nf_ca style
axs[0, 1].set_title('Charging Cost vs Total Volume', fontsize=14)
axs[0, 1].set_xlabel('Total Volume', fontsize=12)
axs[0, 1].set_ylabel('Charging Cost', fontsize=12)
axs[0, 1].tick_params(axis='both', labelsize=10)
axs[0, 1].legend(loc='upper left', fontsize=10)
axs[0, 1].grid(True)

# Plot 3: Penalty Cost vs Total Volume
axs[1, 0].plot(total_volume, penalty_cost_fs, label='Flexible Swap & Smart Charge', linestyle=styles['fs']['line'], marker=styles['fs']['marker'], color=styles['fs']['color'], alpha=0.8)
axs[1, 0].plot(total_volume, penalty_cost_nf, label='Non-Flexible Swap & Smart Charge', linestyle=styles['nf']['line'], marker=styles['nf']['marker'], color=styles['nf']['color'], alpha=0.8)
axs[1, 0].plot(total_volume, penalty_cost_ca, label='Flexible Swap & Charge ASAP', linestyle=styles['ca']['line'], marker=styles['ca']['marker'], color=styles['ca']['color'], alpha=0.8)
axs[1, 0].plot(total_volume, penalty_cost_nf_ca, label='Non-Flexible Swap & Charge ASAP', linestyle=styles['nf_ca']['line'], marker=styles['nf_ca']['marker'], color=styles['nf_ca']['color'], alpha=0.8)  # Using nf_ca style
axs[1, 0].set_title('Penalty Cost vs Total Volume', fontsize=14)
axs[1, 0].set_xlabel('Total Volume', fontsize=12)
axs[1, 0].set_ylabel('Penalty Cost', fontsize=12)
axs[1, 0].tick_params(axis='both', labelsize=10)
axs[1, 0].legend(loc='upper left', fontsize=10)
axs[1, 0].grid(True)

# Plot 4: Swap Income vs Total Volume
'''axs[1, 1].plot(total_volume, swap_income_fs, label='Flexible Swap & Smart Charge', linestyle=styles['fs']['line'], marker=styles['fs']['marker'], color=styles['fs']['color'], alpha=0.8)
axs[1, 1].plot(total_volume, swap_income_nf, label='Non-Flexible Swap', linestyle=styles['nf']['line'], marker=styles['nf']['marker'], color=styles['nf']['color'], alpha=0.8)
axs[1, 1].plot(total_volume, swap_income_ca, label='Charge ASAP', linestyle=styles['ca']['line'], marker=styles['ca']['marker'], color=styles['ca']['color'], alpha=0.8)
axs[1, 1].plot(total_volume, swap_income_nf_ca, label='Non-Flexible Swap & Charge ASAP', linestyle=styles['nf_ca']['line'], marker=styles['nf_ca']['marker'], color=styles['nf_ca']['color'], alpha=0.8)  # Using nf_ca style
axs[1, 1].set_title('Swap Income vs Total Volume', fontsize=14)
axs[1, 1].set_xlabel('Total Volume', fontsize=12)
axs[1, 1].set_ylabel('Swap Income', fontsize=12)
axs[1, 1].tick_params(axis='both', labelsize=10)
axs[1, 1].legend(loc='upper left', fontsize=10)
axs[1, 1].grid(True)'''
# Plot 4: Swap Income vs Total Volume as bar chart
bar_width = 10  # Adjust the width of the bars
index = total_volume  # X-axis positions

# Shift positions for each dataset
offset = bar_width * 0.5  # Adjust the spacing between bars

# Create the bar plots
bars_fs = axs[1, 1].bar(index - 3*offset, swap_income_fs, width=bar_width, label='Flexible Swap & Smart Charge', color=styles['fs']['color'], alpha=0.8)
bars_nf = axs[1, 1].bar(index - offset, swap_income_nf, width=bar_width, label='Non-Flexible Swap & Smart Charge', color=styles['nf']['color'], alpha=0.8)
bars_ca = axs[1, 1].bar(index + offset, swap_income_ca, width=bar_width, label='Flexible Swap & Charge ASAP', color=styles['ca']['color'], alpha=0.8)
bars_nf_ca = axs[1, 1].bar(index + 3*offset, swap_income_nf_ca, width=bar_width, label='Non-Flexible Swap & Charge ASAP', color=styles['nf_ca']['color'], alpha=0.8)

# Set title and labels
axs[1, 1].set_title('Swap Income vs Total Volume', fontsize=14)
axs[1, 1].set_xlabel('Total Volume', fontsize=12)
axs[1, 1].set_ylabel('Swap Income', fontsize=12)

# Add legend
axs[1, 1].legend(loc='upper left', fontsize=10)

# Grid and tick parameters
axs[1, 1].tick_params(axis='both', labelsize=10)
axs[1, 1].grid(True)

# Set the y-axis limit to match the range of the swap_income values
axs[1, 1].set_ylim([0, max(swap_income_fs) * 1.1])

# Optional: fine-tune x-ticks and labels if needed
axs[1, 1].set_xticks(index)  # Align the x-ticks with the total volume
axs[1, 1].set_xticklabels(total_volume, fontsize=10)




# Adjust layout to prevent overlap
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 数据
labels = ['灵活换电和智能充电', '固定换电和智能充电', '灵活换电和即时充电', '固定换电和即时充电']
I_S = [28812, 27604, 28773.25, 27604]
C_C = [14896.75, 14394.25, 20081, 19015.25]
C_P = [1890, 4380, 1890, 4380]

plt.rcParams.update({
    'font.family': 'SimSun',  # or 'Helvetica'
    'font.size': 12,  # Default font size for axis labels and ticks
    'lines.linewidth': 2,  # Line width for better visibility
    'axes.grid': True,  # Turn on grid
    'grid.alpha': 0.3  # Make the grid lighter to match SCI standards
})
# x 轴的位置
x = np.arange(len(labels))

# 设置柱状图的宽度
width = 1

# 定义每个柱子对应的颜色
colors_for_bars = [
    (33/255, 29/255, 31/255),  # 灵活换电和智能充电
    (11/255, 112/255, 183/255),  # 匹配换电和智能充电
    (242/255, 146/255, 33/255),  # 灵活换电和固定充电
    (126/255, 204/255, 37/255)   # 匹配换电和固定充电
]

# 创建图形和子图
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(8, 6),dpi=150)

# 绘制第一个柱状图 I_S
ax1.bar(x , I_S, width, label='I_S', color=colors_for_bars,alpha=0.8)
#ax1.set_ylabel('换电收入',fontsize=12)
ax1.set_title('换电收入',fontsize=14)
ax1.set_xticks(x)
ax1.set_xticklabels(labels, rotation=45, ha='right')

# 绘制第二个柱状图 C_C
ax2.bar(x , C_C, width, label='C_C', color=colors_for_bars,alpha=0.8)
#ax2.set_ylabel('充电成本',fontsize=12)
ax2.set_title('充电成本',fontsize=14)
ax2.set_xticks(x)
ax2.set_xticklabels(labels, rotation=45, ha='right')

# 绘制第三个柱状图 C_P
ax3.bar(x , C_P, width, label='C_P', color=colors_for_bars,alpha=0.8)
#ax3.set_ylabel('惩罚成本',fontsize=12)
ax3.set_title('惩罚成本',fontsize=14)
ax3.set_xticks(x)
ax3.set_xticklabels(labels, rotation=45, ha='right')

# 自动调整布局
plt.tight_layout()

# 显示图形
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Example data
total_volume = np.array([50, 100, 150, 200, 250, 300, 350])

# Monetary Income
monetary_income_fs = np.array([4485.75, 6658.5, 8493.25, 9760.5, 10240, 10660.5, 10658.25])
monetary_income_nf = np.array([4226, 6010.25, 7548.25, 8916.5, 9720.75, 10631.5, 11398.75])
monetary_income_ca = np.array([2530.75, 3448, 3930.75, 4288.75, 4047.5, 3770.25, 3428])
monetary_income_nf_ca = np.array([2508, 2825, 3141.25, 2919, 3696, 3975, 4397.5])

# Service Rate
service_rate_fs = np.array([99.40, 99.60, 99.60, 99.50, 99.68, 99.47, 98.71])
service_rate_nf = np.array([99.20, 98.40, 98.40, 98.75, 98.08, 96.83, 94.66])
service_rate_ca = np.array([99.40, 99.20, 99.13, 99.10, 99.12, 99.00, 97.97])
service_rate_nf_ca = np.array([98.20, 97.40, 97.53, 98.30, 96.72, 95.83, 93.89])


# Set global font properties for all plots
plt.rcParams.update({
    'font.family': 'SimSun',  # or 'Helvetica'
    'font.size': 12,  # Default font size for axis labels and ticks
    'lines.linewidth': 2,  # Line width for better visibility
    'axes.grid': True,  # Turn on grid
    'grid.alpha': 0.3  # Make the grid lighter to match SCI standards
})

# Create figure and axis
fig, ax1 = plt.subplots(figsize=(8, 8), dpi=200)

# Bar width
bar_width = 10
index = total_volume

# Shift positions for each dataset
offset = bar_width * 0.5  # Adjust the spacing between groups
bars_fs = ax1.bar(index - 3*offset, monetary_income_fs, width=bar_width, label='经济收益 (灵活换电 & 智能充电)', color=styles['fs']['color'], alpha=0.8)
bars_nf = ax1.bar(index - offset, monetary_income_nf, width=bar_width, label='经济收益 (固定换电 & 智能充电)', color=styles['nf']['color'], alpha=0.8)
bars_ca = ax1.bar(index + offset, monetary_income_ca, width=bar_width, label='经济收益 (灵活换电 & 即时充电)', color=styles['ca']['color'], alpha=0.8)
bars_nf_ca = ax1.bar(index + 3 * offset, monetary_income_nf_ca, width=bar_width, label='经济收益 (固定换电 & 即时充电)', color=styles['nf_ca']['color'], alpha=0.8)

# Set the axis labels and title
ax1.set_xlabel('总流量', fontsize=12)
ax1.set_ylabel('经济收益', fontsize=12)
ax1.set_xticks(index)  # Align the x-ticks with the total volume
ax1.set_xticklabels(total_volume, fontsize=10)
ax1.set_ylim([0, 16000])

# Create second axis for Service Rate (right y-axis)
ax2 = ax1.twinx()
lines_fs, = ax2.plot(total_volume, service_rate_fs, label='服务率 (灵活换电 & 智能充电)', linestyle=styles['fs']['line'], marker=styles['fs']['marker'], color=styles['fs']['color'], alpha=0.8)
lines_nf, = ax2.plot(total_volume, service_rate_nf, label='服务率 (固定换电 & 智能充电)', linestyle=styles['nf']['line'], marker=styles['nf']['marker'], color=styles['nf']['color'], alpha=0.8)
lines_ca, = ax2.plot(total_volume, service_rate_ca, label='服务率 (灵活换电 & 即时充电)', linestyle=styles['ca']['line'], marker=styles['ca']['marker'], color=styles['ca']['color'], alpha=0.8)
lines_nf_ca, = ax2.plot(total_volume, service_rate_nf_ca, label='服务率 (固定换电 & 即时充电)', linestyle=styles['nf_ca']['line'], marker=styles['nf_ca']['marker'], color=styles['nf_ca']['color'], alpha=0.8)

# Set second axis labels
ax2.set_ylabel('服务率 (%)', fontsize=12)
ax2.set_ylim([80, 100])

# Combine legends from both axes into one (Monetary Income and Service Rate separately)
lines = [lines_fs, lines_nf, lines_ca, lines_nf_ca]  # Lines for service rate
bars = [bars_fs, bars_nf, bars_ca, bars_nf_ca]  # Bars for monetary income

# Create combined legend
handles = lines + bars
labels = [line.get_label() for line in lines] + [bar.get_label() for bar in bars]

# Move the legend outside the plot
ax1.legend(handles, labels, fontsize=10, loc='upper center', bbox_to_anchor=(0.5, -0.15), borderaxespad=0.)

# Set grid and fine-tune layout
ax1.grid(True, which='both', axis='y', linestyle='--', alpha=0.7)
ax1.tick_params(axis='both', which='both', length=0)  # Remove tick marks for a cleaner look

# Set plot title
#plt.title('服务率与经济收益与总流量的关系', fontsize=14)

# Fine-tune layout
fig.tight_layout()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Set global font properties for all plots
plt.rcParams.update({
    'font.family': 'SimSun',  # or 'Helvetica'
    'font.size': 12,  # Default font size for axis labels and ticks
    'lines.linewidth': 2,  # Line width for better visibility
    'axes.grid': True,  # Turn on grid
    'grid.alpha': 0.3  # Make the grid lighter to match SCI standards
})

# Create a 2x2 grid of subplots
fig, axs = plt.subplots(2, 2, figsize=(10, 12),dpi=200)

# Plot 1: Battery Cost vs Total Volume
axs[0, 0].plot(total_volume, battery_cost_fs, label='灵活换电 & 智能充电', linestyle=styles['fs']['line'], marker=styles['fs']['marker'], color=styles['fs']['color'], alpha=0.8)
axs[0, 0].plot(total_volume, battery_cost_nf, label='固定换电 & 智能充电', linestyle=styles['nf']['line'], marker=styles['nf']['marker'], color=styles['nf']['color'], alpha=0.8)
axs[0, 0].plot(total_volume, battery_cost_ca, label='灵活换电 & 即时充电', linestyle=styles['ca']['line'], marker=styles['ca']['marker'], color=styles['ca']['color'], alpha=0.8)
axs[0, 0].plot(total_volume, battery_cost_nf_ca, label='固定换电 & 即时充电', linestyle=styles['nf_ca']['line'], marker=styles['nf_ca']['marker'], color=styles['nf_ca']['color'], alpha=0.8)  # Using nf_ca style
axs[0, 0].set_title('电池成本与总流量的关系', fontsize=14)
axs[0, 0].set_xlabel('总流量', fontsize=12)
axs[0, 0].set_ylabel('电池成本', fontsize=12)
axs[0, 0].tick_params(axis='both', labelsize=10)  # Set tick label size
axs[0, 0].legend(loc='upper left', fontsize=10)
axs[0, 0].grid(True)

# Plot 2: Charging Cost vs Total Volume
axs[0, 1].plot(total_volume, charging_cost_fs, label='灵活换电 & 智能充电', linestyle=styles['fs']['line'], marker=styles['fs']['marker'], color=styles['fs']['color'], alpha=0.8)
axs[0, 1].plot(total_volume, charging_cost_nf, label='固定换电 & 智能充电', linestyle=styles['nf']['line'], marker=styles['nf']['marker'], color=styles['nf']['color'], alpha=0.8)
axs[0, 1].plot(total_volume, charging_cost_ca, label='灵活换电 & 即时充电', linestyle=styles['ca']['line'], marker=styles['ca']['marker'], color=styles['ca']['color'], alpha=0.8)
axs[0, 1].plot(total_volume, charging_cost_nf_ca, label='固定换电 & 即时充电', linestyle=styles['nf_ca']['line'], marker=styles['nf_ca']['marker'], color=styles['nf_ca']['color'], alpha=0.8)  # Using nf_ca style
axs[0, 1].set_title('充电成本与总流量的关系', fontsize=14)
axs[0, 1].set_xlabel('总流量', fontsize=12)
axs[0, 1].set_ylabel('充电成本', fontsize=12)
axs[0, 1].tick_params(axis='both', labelsize=10)
axs[0, 1].legend(loc='upper left', fontsize=10)
axs[0, 1].grid(True)

# Plot 3: Penalty Cost vs Total Volume
axs[1, 0].plot(total_volume, penalty_cost_fs, label='灵活换电 & 智能充电', linestyle=styles['fs']['line'], marker=styles['fs']['marker'], color=styles['fs']['color'], alpha=0.8)
axs[1, 0].plot(total_volume, penalty_cost_nf, label='固定换电 & 智能充电', linestyle=styles['nf']['line'], marker=styles['nf']['marker'], color=styles['nf']['color'], alpha=0.8)
axs[1, 0].plot(total_volume, penalty_cost_ca, label='灵活换电 & 即时充电', linestyle=styles['ca']['line'], marker=styles['ca']['marker'], color=styles['ca']['color'], alpha=0.8)
axs[1, 0].plot(total_volume, penalty_cost_nf_ca, label='固定换电 & 即时充电', linestyle=styles['nf_ca']['line'], marker=styles['nf_ca']['marker'], color=styles['nf_ca']['color'], alpha=0.8)  # Using nf_ca style
axs[1, 0].set_title('惩罚成本与总流量的关系', fontsize=14)
axs[1, 0].set_xlabel('总流量', fontsize=12)
axs[1, 0].set_ylabel('惩罚成本', fontsize=12)
axs[1, 0].tick_params(axis='both', labelsize=10)
axs[1, 0].legend(loc='upper left', fontsize=10)
axs[1, 0].grid(True)

# Plot 4: Swap Income vs Total Volume
'''axs[1, 1].plot(total_volume, swap_income_fs, label='灵活换电 & 智能充电', linestyle=styles['fs']['line'], marker=styles['fs']['marker'], color=styles['fs']['color'], alpha=0.8)
axs[1, 1].plot(total_volume, swap_income_nf, label='固定换电', linestyle=styles['nf']['line'], marker=styles['nf']['marker'], color=styles['nf']['color'], alpha=0.8)
axs[1, 1].plot(total_volume, swap_income_ca, label='即时充电', linestyle=styles['ca']['line'], marker=styles['ca']['marker'], color=styles['ca']['color'], alpha=0.8)
axs[1, 1].plot(total_volume, swap_income_nf_ca, label='固定换电 & 即时充电', linestyle=styles['nf_ca']['line'], marker=styles['nf_ca']['marker'], color=styles['nf_ca']['color'], alpha=0.8)  # Using nf_ca style
axs[1, 1].set_title('换电收入与总流量的关系', fontsize=14)
axs[1, 1].set_xlabel('总流量', fontsize=12)
axs[1, 1].set_ylabel('换电收入', fontsize=12)
axs[1, 1].tick_params(axis='both', labelsize=10)
axs[1, 1].legend(loc='upper left', fontsize=10)
axs[1, 1].grid(True)'''

# Plot 4: Swap Income vs Total Volume as bar chart
bar_width = 10  # Adjust the width of the bars
index = total_volume  # X-axis positions

# Shift positions for each dataset
offset = bar_width * 0.5  # Adjust the spacing between bars

# Create the bar plots
bars_fs = axs[1, 1].bar(index - 3*offset, swap_income_fs, width=bar_width, label='灵活换电 & 智能充电', color=styles['fs']['color'], alpha=0.8)
bars_nf = axs[1, 1].bar(index - offset, swap_income_nf, width=bar_width, label='固定换电 & 智能充电', color=styles['nf']['color'], alpha=0.8)
bars_ca = axs[1, 1].bar(index + offset, swap_income_ca, width=bar_width, label='灵活换电 & 即时充电', color=styles['ca']['color'], alpha=0.8)
bars_nf_ca = axs[1, 1].bar(index + 3*offset, swap_income_nf_ca, width=bar_width, label='固定换电 & 即时充电', color=styles['nf_ca']['color'], alpha=0.8)

# Set title and labels
axs[1, 1].set_title('换电收入与总流量的关系', fontsize=14)
axs[1, 1].set_xlabel('总流量', fontsize=12)
axs[1, 1].set_ylabel('换电收入', fontsize=12)

# Add legend
axs[1, 1].legend(loc='upper left', fontsize=10)

# Grid and tick parameters
axs[1, 1].tick_params(axis='both', labelsize=10)
axs[1, 1].grid(True)

# Set the y-axis limit to match the range of the swap_income values
axs[1, 1].set_ylim([0, max(swap_income_fs) * 1.1])

# Optional: fine-tune x-ticks and labels if needed
axs[1, 1].set_xticks(index)  # Align the x-ticks with
